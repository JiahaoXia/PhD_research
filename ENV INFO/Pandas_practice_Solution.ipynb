# %%
import os
import numpy as np
import pandas as pd
from IPython.display import Image
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
os.getcwd()
# Out:
# '/Users/rqwang/Google Drive/050_Teaching/2019_env_analysis_tools/Python_materials'

# %%
data = pd.read_csv('../Quiz/StateSAT.csv')
data.head()
# Out:
#         STATE REGION  EXPENDITURE_PER_PUPIL  PUPIL_TEACHER_RATIO  \
# 0     Alabama  South                  4.405                 17.2
# 1      Alaska   West                  8.963                 17.6
# 2     Arizona   West                  4.778                 19.3
# 3    Arkansas  South                  4.459                 17.1
# 4  California   West                  4.992                 24.0
#
#    TEACHER_SALARY  PERCENT_TAKING  SAT_VERBAL  SAT_MATH  SAT_TOTAL
# 0          31.144               8         491       538       1029
# 1          47.951              47         445       489        934
# 2          32.175              27         448       496        944
# 3          28.934               6         482       523       1005
# 4          41.078              45         417       485        902

# %%
data.describe()
# Out:
#        EXPENDITURE_PER_PUPIL  PUPIL_TEACHER_RATIO  TEACHER_SALARY  \
# count              50.000000            50.000000       50.000000
# mean                5.905260            16.858000       34.828920
# std                 1.362807             2.266355        5.941265
# min                 3.656000            13.800000       25.994000
# 25%                 4.881750            15.225000       30.977500
# 50%                 5.767500            16.600000       33.287500
# 75%                 6.434000            17.575000       38.545750
# max                 9.774000            24.300000       50.045000
#
#        PERCENT_TAKING  SAT_VERBAL    SAT_MATH    SAT_TOTAL
# count       50.000000   50.000000   50.000000    50.000000
# mean        35.240000  457.140000  508.780000   965.920000
# std         26.762417   35.175948   40.204726    74.820558
# min          4.000000  401.000000  443.000000   844.000000
# 25%          9.000000  427.250000  474.750000   897.250000
# ...

# %%
data[data.SAT_TOTAL>1080]
# Out:
#            STATE   REGION  EXPENDITURE_PER_PUPIL  PUPIL_TEACHER_RATIO  \
# 14          Iowa  Midwest                  5.483                 15.8
# 22     Minnesota  Midwest                  6.000                 17.5
# 33  North Dakota     West                  4.775                 15.3
#
#     TEACHER_SALARY  PERCENT_TAKING  SAT_VERBAL  SAT_MATH  SAT_TOTAL
# 14          31.511               5         516       583       1099
# 22          35.948               9         506       579       1085
# 33          26.327               5         515       592       1107

# %%
data[data.REGION=='Northeast']
# Out:
#             STATE     REGION  EXPENDITURE_PER_PUPIL  PUPIL_TEACHER_RATIO  \
# 6     Connecticut  Northeast                  8.817                 14.4
# 7        Delaware  Northeast                  7.030                 16.6
# 18          Maine  Northeast                  6.428                 13.8
# 20  Massachusetts  Northeast                  7.287                 14.8
# 28  New Hampshire  Northeast                  5.859                 15.6
# 29     New Jersey  Northeast                  9.774                 13.8
# 31       New York  Northeast                  9.623                 15.2
# 37   Pennsylvania  Northeast                  7.109                 17.1
# 38   Rhode Island  Northeast                  7.469                 14.7
# 44        Vermont  Northeast                  6.750                 13.8
#
#     TEACHER_SALARY  PERCENT_TAKING  SAT_VERBAL  SAT_MATH  SAT_TOTAL
# 6           50.045              81         431       477        908
# ...

# %%
data.iloc[12,-3:]
# Out:
# SAT_VERBAL     488
# SAT_MATH       560
# SAT_TOTAL     1048
# Name: 12, dtype: object

# %%
data.plot.bar(x='STATE',y='SAT_MATH')

# %%
data.plot.scatter(x='SAT_TOTAL',y='PERCENT_TAKING')
